# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
x = np.random.rand(10000) - 1/2
mu = 1/2
sig = 1/12
y = [ i**(1/2)*x[i] for i in range(len(x))]
xs = np.linspace(min(y),max(y),1000)
ys = norm(loc = 0,scale = np.std(y)).pdf(xs)
plt.hist(y, bins =20, density = True)
plt.plot(xs,ys)
plt.show()
print(mu,sig,np.std(y))
# Out:
# 0.5 0.08333333333333333 20.3197246000717

# %%
x = np.random.rand(10000)
mu = np.mean(np.log(x))
x = np.log(x)
sig = np.std(x)
# sig = np.std(x)
y = [ i**(1/2)*(x[i] - mu) for i in range(len(x))]
xs = np.linspace(min(y),max(y),1000)
ys = norm(loc = 0,scale = np.std(y)).pdf(xs)
plt.hist(y, bins =20, density = True)
plt.plot(xs,ys)
plt.show()

# %%
def logit(x):
    return np.log(x/(1-x))

x = np.random.rand(10000)
mu = np.mean(np.log(x))
x = np.log(x)
sig = np.std(x)
# sig = np.std(x)
y = [ i**(1/2)*(x[i] - mu) for i in range(len(x))]
xs = np.linspace(min(y),max(y),1000)
ys = norm(loc = 0,scale = np.std(y)).pdf(xs)
plt.hist(y, bins =20, density = True)
plt.plot(xs,ys)
plt.show()
# Out:
# 1.0190636158701682
